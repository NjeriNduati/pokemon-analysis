# %%
a="hello"
a
# Out:
# 'hello'

# %%
import numpy as np

# %%
a=np.array([1,2,4,6])
a
# Out:
# array([1, 2, 4, 6])

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
df.describe()
# Out:
#           Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  721.00000  721.000000  721.000000  721.000000  721.000000  721.000000
# mean   361.00000  417.945908   68.380028   75.013870   70.808599   68.737864
# std    208.27906  109.663671   25.848272   28.984475   29.296558   28.788005
# min      1.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    181.00000  320.000000   50.000000   53.000000   50.000000   45.000000
# 50%    361.00000  424.000000   65.000000   74.000000   65.000000   65.000000
# 75%    541.00000  499.000000   80.000000   95.000000   85.000000   90.000000
# max    721.00000  720.000000  255.000000  165.000000  230.000000  154.000000
#
#            Sp_Def       Speed  Generation     Pr_Male    Height_m   Weight_kg  \
# count  721.000000  721.000000  721.000000  644.000000  721.000000  721.000000
# mean    69.291262   65.714286    3.323162    0.553377    1.144979   56.773370
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Number            721 non-null    int64
#  1   Name              721 non-null    object
#  2   Type_1            721 non-null    object
#  3   Type_2            350 non-null    object
#  4   Total             721 non-null    int64
#  5   HP                721 non-null    int64
#  6   Attack            721 non-null    int64
#  7   Defense           721 non-null    int64
#  8   Sp_Atk            721 non-null    int64
#  9   Sp_Def            721 non-null    int64
#  10  Speed             721 non-null    int64
#  11  Generation        721 non-null    int64
#  12  isLegendary       721 non-null    bool
#  13  Color             721 non-null    object
#  14  hasGender         721 non-null    bool
#  15  Pr_Male           644 non-null    float64
# ...

# %% [markdown]
# BASIC FILTERING

# %%
df['Strength']=df['Attack']+df['Defense']+df['HP']
df.head(5)
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    143  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    185  60      62       63      80
# 2       3    Venusaur  Grass  Poison    245  80      82       83     100
# 3       4  Charmander   Fire     NaN    134  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    180  58      64       58      80
#
#    Sp_Def  ...  hasGender  Pr_Male  Egg_Group_1 Egg_Group_2  hasMegaEvolution  \
# 0      65  ...       True    0.875      Monster       Grass             False
# 1      80  ...       True    0.875      Monster       Grass             False
# 2     100  ...       True    0.875      Monster       Grass              True
# 3      50  ...       True    0.875      Monster      Dragon             False
# 4      65  ...       True    0.875      Monster      Dragon             False
#
# ...

# %% [markdown]
# **QSTN:How many pokemon exist with an attack greater than 150**

# %%
df.loc[df['Attack']>150]
# Out:
#      Number       Name  Type_1 Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 288     289    Slaking  Normal    NaN    670  150     160      100      95
# 408     409  Rampardos    Rock    NaN    495   97     165       60      65
# 485     486  Regigigas  Normal    NaN    670  110     160      110      80
#
#      Sp_Def  ...  Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 288      65  ...  Brown       True    0.500         Field          NaN
# 408      50  ...   Blue       True    0.875       Monster          NaN
# 485     110  ...  White      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate        Body_Style
# 288             False     2.01     130.5          45  bipedal_tailless
# 408             False     1.60     102.5          45    bipedal_tailed
# 485             False     3.71     420.0           3  bipedal_tailless
#
# [3 rows x 23 columns]

# %%
df.query('Attack> 150')
# Out:
#      Number       Name  Type_1 Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 288     289    Slaking  Normal    NaN    670  150     160      100      95
# 408     409  Rampardos    Rock    NaN    495   97     165       60      65
# 485     486  Regigigas  Normal    NaN    670  110     160      110      80
#
#      Sp_Def  ...  Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 288      65  ...  Brown       True    0.500         Field          NaN
# 408      50  ...   Blue       True    0.875       Monster          NaN
# 485     110  ...  White      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate        Body_Style
# 288             False     2.01     130.5          45  bipedal_tailless
# 408             False     1.60     102.5          45    bipedal_tailed
# 485             False     3.71     420.0           3  bipedal_tailless
#
# [3 rows x 23 columns]

# %% [markdown]
# **QSTN2: SELECT ALL POKEMEN WITH A SPEED LESS OR 10 AND STORE IN YOUR RESULT IN A VARIABLE CALLED SLOW_POKEMEN**

# %%
slow_pokemen =df.loc[df['Speed']<=10]
slow_pokemen
# Out:
#      Number       Name  Type_1 Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 212     213    Shuckle     Bug   Rock    505   20      10      230      10
# 327     328   Trapinch  Ground    NaN    290   45     100       45      45
# 437     438     Bonsly    Rock    NaN    290   50      80       95      10
# 445     446   Munchlax  Normal    NaN    390  135      85       40      40
# 596     597  Ferroseed   Grass  Steel    305   44      50       91      24
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 212     230  ...  Yellow       True    0.500           Bug          NaN
# 327      45  ...   Brown       True    0.500           Bug          NaN
# 437      45  ...   Brown       True    0.500  Undiscovered          NaN
# 445      85  ...   Black       True    0.875  Undiscovered          NaN
# 596      86  ...    Grey       True    0.500         Grass      Mineral
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate        Body_Style
# ...

# %% [markdown]
# **QSTN3:HOW MANY POKEMEN HAVE A SP_DEF OF LESS THAN 25**

# %%
(df['Sp_Def']<25).sum()
# Out:
# 6

# %% [markdown]
# **QSTN4:SELECT only THE LEGENDARY POKEMEN AND STORE THE RESULT IN A VARIABLE CALLED legendary_df**

# %%
df['isLegendary'].sum()
# Out:
# 46

# %%
legendary_df=df.loc[df['isLegendary']]
legendary_df.head()
# Out:
#      Number      Name    Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 143     144  Articuno       Ice  Flying    580   90      85      100      95
# 144     145    Zapdos  Electric  Flying    580   90      90       85     125
# 145     146   Moltres      Fire  Flying    580   90     100       90     125
# 149     150    Mewtwo   Psychic     NaN    680  106     110       90     154
# 242     243    Raikou  Electric     NaN    580   90      85       75     115
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 143     125  ...    Blue      False      NaN  Undiscovered          NaN
# 144      90  ...  Yellow      False      NaN  Undiscovered          NaN
# 145      85  ...  Yellow      False      NaN  Undiscovered          NaN
# 149      90  ...  Purple      False      NaN  Undiscovered          NaN
# 242     100  ...  Yellow      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
df.plot.scatter(x='Defense', y='Attack', color='blue', marker='o', s=50)
# Out:
# <Axes: xlabel='Defense', ylabel='Attack'>

# %% [markdown]
# **QSTN5:REFERRING TO THE PLOT ABOVE,FIND THE OUTLIER
#     FIND THE POKEMAN WITH THE STRONGEST DEFENSE BUT VERY SLOW ATTACK**

# %%
df.loc[df['Defense']>200]
# Out:
#      Number     Name Type_1 Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 212     213  Shuckle    Bug   Rock    505  20      10      230      10
#
#      Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 212     230  ...  Yellow       True      0.5         Bug          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate  Body_Style
# 212             False     0.61      20.5         190   insectoid
#
# [1 rows x 23 columns]

# %% [markdown]
# **QSTN6:HOW MANY TYPES OF FIRE-FLYING POKEMEN ARE THERE;how many pokemen are of *Type1:Fire* and *Type2:Flying* **

# %%
((df['Type_1']=='Fire')&(df['Type_2']=='Flying')).sum()
# Out:
# 5

# %%
df.loc[(df['Type_1']=='Fire') & (df['Type_2']=='Flying')]
# Out:
#      Number         Name Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 5         6    Charizard   Fire  Flying    534   78      84       78     109
# 145     146      Moltres   Fire  Flying    580   90     100       90     125
# 249     250        Ho-Oh   Fire  Flying    680  106     130       90     110
# 661     662  Fletchinder   Fire  Flying    382   62      73       55      56
# 662     663   Talonflame   Fire  Flying    499   78      81       71      74
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 5        85  ...     Red       True    0.875       Monster       Dragon
# 145      85  ...  Yellow      False      NaN  Undiscovered          NaN
# 249     154  ...     Red      False      NaN  Undiscovered          NaN
# 661      52  ...     Red       True    0.500        Flying          NaN
# 662      69  ...     Red       True    0.500        Flying          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %% [markdown]
# **QSTN7:HOW MANY POKEMEN EXIST THAT ARE OF TYPE 'POISON' IN EITHER TYPE_1 OR TYPE_2**

# %%
df['Type_1'].value_counts()
# Out:
# Type_1
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Fire         47
# Psychic      47
# Rock         41
# Electric     36
# Ground       30
# Poison       28
# Dark         28
# Fighting     25
# Dragon       24
# Ghost        23
# Ice          23
# Steel        22
# Fairy        17
# Flying        3
# Name: count, dtype: int64

# %%
df['Type_2'].value_counts()
# Out:
# Type_2
# Flying      87
# Poison      31
# Ground      30
# Psychic     27
# Fighting    19
# Steel       19
# Fairy       18
# Grass       18
# Dark        16
# Dragon      14
# Rock        14
# Water       13
# Ghost       12
# Ice         10
# Fire         9
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
((df['Type_1']=='Poison') | (df['Type_2']=='Poison')).sum()
# Out:
# 59
